# %% [markdown]
# # **Intruduction Section**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')
#df = df.head(768)
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#missing = df.AGE.mean()

# %%
#df.AGE = df.AGE.fillna(missing)
#df.isnull().sum()

# %%
x =  df.drop(['Outcome'], axis=1)
y = df['Outcome']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    1
# 1999    0
# Name: Outcome, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.20, random_state=1)

# %%
xtrain
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 816             1      139             46             19       83  28.7
# 790             4      129             60             12      231  27.5
# 361             5      158             70              0        0  29.8
# 592             3      132             80              0        0  34.4
# ...           ...      ...            ...            ...      ...   ...
# 1791            2      129              0              0        0  38.5
# 1096            1      100             74             12       46  19.5
# 1932            8      155             62             26      495  34.0
# 235             4      171             72              0        0  43.6
# 1061            4      183              0              0        0  28.4
#
#       DiabetesPedigreeFunction  Age
# 0                        0.127   47
# ...

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
desTreeModel = DecisionTreeClassifier()
desTreeModel.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
desTreeModel.score(xtest,ytest)
# Out:
# 0.95

# %% [markdown]
# # **Support Vector Machine**

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model.score(xtest,ytest)
# Out:
# 0.7775

# %%
model.score(xtrain,ytrain)
# Out:
# 0.775

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randomModel = RandomForestClassifier()
randomModel.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
randomModel.score(xtest,ytest)
# Out:
# 0.97

# %% [markdown]
# # **Xboost**

# %%
from xgboost import XGBClassifier

# %%
xboostCls = XGBClassifier()
xboostCls.fit(xtrain,ytrain)
# Out:
# XGBClassifier()

# %%
xboostCls.score(xtest,ytest)
# Out:
# 0.845

# %% [markdown]
# # **Gradient Booster**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradientCls = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0)
gradientCls.fit(xtrain,ytrain)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, random_state=0)

# %%
gradientCls.score(xtest,ytest)
# Out:
# 0.85

# %% [markdown]
# # **Logistic** **regression**

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()

# %%
logisticRegr.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
logisticRegr.score(xtest,ytest)
# Out:
# 0.7875

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
knnCls = KNeighborsClassifier()

# %%
knnCls.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
knnCls.score(xtest,ytest)
# Out:
# 0.8175

# %% [markdown]
# # **Convolitional Nural Network**

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

import keras
from keras.models import Sequential
from keras.layers import Dense

from keras.layers import Dropout

classifier = Sequential()
classifier.add(Dense(16,activation='relu',input_dim=8))
classifier.add(Dropout(0.2))

#adding the second hidden layer
classifier.add(Dense(16,activation='relu'))
classifier.add(Dropout(0.2))
#adding third layer
classifier.add(Dense(32,activation='relu'))
classifier.add(Dropout(0.2))

#adding the output layer
classifier.add(Dense(1,activation='sigmoid'))

classifier.compile(optimizer="Adam", loss='binary_crossentropy', metrics=['accuracy'])

classifier.fit(xtrain, ytrain, batch_size=100, epochs=100)

y_pred = classifier.predict(xtest)
y_pred = (y_pred > 0.5)



#sns.heatmap(cm,annot=True)
#plt.savefig('h.png')
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 2ms/step - loss: 0.6827 - accuracy: 0.5562
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6372 - accuracy: 0.6850
# Epoch 3/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6057 - accuracy: 0.6975
# Epoch 4/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.7025
# Epoch 5/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5740 - accuracy: 0.7031
# Epoch 6/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5436 - accuracy: 0.7306
# Epoch 7/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5434 - accuracy: 0.7256
# Epoch 8/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.7269
# Epoch 9/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5309 - accuracy: 0.7344
# Epoch 10/100
# ...

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 16)                144
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 16)                272
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_6 (Dense)             (None, 32)                544
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# ...
# Total params: 993
# Trainable params: 993
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(ytest, y_pred)
cm
# Out:
# array([[228,  41],
#        [ 49,  82]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest, y_pred)
# Out:
# 0.775
